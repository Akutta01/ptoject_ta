# %% [markdown]
# ### Elizabeth Koquer Gyau
# ### 11216181
# ### Biomedical Engineering

# %%
#Importing Pandas
import pandas as pd

# %%
#Importing Matplotlib
import matplotlib.pyplot as plt

# %%
#Importing Numpy
import numpy as np

# %%
#Import from CSV file
dataset= pd.read_csv('modified red_wine.csv')

# %%
#View Data
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Check Head
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#Check Tail
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
#Check Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
#Check Description
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=dataset.fillna(2.5)

# %%
y
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
y.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
y.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
import matplotlib.pyplot as plt

# %%
#Line Plot
plt.plot(y['free sulfur dioxide'])

# %%
#Line Plot
plt.plot(y['density'])

# %%
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
xlabel=('X-axis label')

# %%
ylabel=('Y-axis label')

# %%
#Scatter Plot
plt.scatter(y['free sulfur dioxide'], y['density'])

# %%
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.xlabel=('Alcohol Content')

# %%
plt.ylabel=('Frequency')

# %%
plt.figure(figsize=(10,6))

# %%
plt.title('Relative Distribution of Alcohol Content')
# Out:
# Text(0.5, 1.0, 'Relative Distribution of Alcohol Content')

# %%
plt.xlabel=('Alcohol Content')

# %%
plt.ylabel=('Frequency')

# %%
#Advanced Plots with Seaborn
import seaborn as sns

# %%
sns.pairplot(y)
# Out:
# C:\Users\Akutta Francis\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Correlation between variables
correlation_matrix = y.corr()

# %%
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Akutta Francis\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
column_name = 'free sulfur dioxide'

# %%
# Plotting the histogram
plt.hist(y[column_name],bins=20, color='red', edgecolor='black', alpha=0.7)
# Out:
# (array([ 95., 370., 200., 260., 167., 132.,  90., 106.,  58.,  55.,  25.,
#          14.,   5.,   6.,   9.,   3.,   0.,   0.,   3.,   1.]),
#  array([ 1.  ,  4.55,  8.1 , 11.65, 15.2 , 18.75, 22.3 , 25.85, 29.4 ,
#         32.95, 36.5 , 40.05, 43.6 , 47.15, 50.7 , 54.25, 57.8 , 61.35,
#         64.9 , 68.45, 72.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title(f'Histogram of {column_name}')
# Out:
# Text(0.5, 1.0, 'Histogram of free sulfur dioxide')

# %%
plt.xlabel=(column_name)

# %%
plt.ylabel=('Frequency')

# %%
column_name1 = 'density'

# %%
plt.hist(y[column_name1],bins=20, color='red', edgecolor='black', alpha=0.7)
# Out:
# (array([1.598e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([0.99007  , 1.0655665, 1.141063 , 1.2165595, 1.292056 , 1.3675525,
#         1.443049 , 1.5185455, 1.594042 , 1.6695385, 1.745035 , 1.8205315,
#         1.896028 , 1.9715245, 2.047021 , 2.1225175, 2.198014 , 2.2735105,
#         2.349007 , 2.4245035, 2.5      ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title(f'Histogram of {column_name1}')
# Out:
# Text(0.5, 1.0, 'Histogram of density')

# %%
plt.xlabel=(column_name1)

# %%
plt.ylabel=('Frequency')

# %% [markdown]
# #Using Markdown to report on all plots and graphs obtained
# # Exploratory Data Analysis Report
#
# ## Line Plot
#
# >Description of the line plot
#
#  The line plot for the free sulfur dioxide of the alcohol displays trunctaed signals of its frequencies which displays how the truncated signals for the free sulfur dioxide act in only one direction rather than in a wave-line manner. However, for the line plot for the density of the alcohol displays its truncated signals acting in a regular pattern.
#   ```python
#   print(plt.plot(dataset['free sulfur dioxide']))
#   print(plt.plot(dataset['density']))
#    ```
#
#   ```jupyter notebook
#     plt.plot(dataset['free sulfur dioxide'])
#     plt.plot(dataset['density'])
#   ```
# ## Scatter Plot
# >Description of the scatter plot
#
#  Since both the frequencies for the free sulfur dioxide and density have close consistent values for each of them, this tends to make the scatter   diagram have plotted points close to each other.
#
# ## Advanced plots with seaborn
# >Description of the Advanced plots with seaborn
#
# Advanced plots with seaborn present various graphs of all contents of the alcohol(red wine). With this display, scatter diagrams and histograms show these contents have in relation with each other with respect to their frequencies.
#
# ## Data correlation for the relative distribution contents of the alcohol
# >Description of the Data correlation
#
# The data correlation for the relative distribution contents of the alcohol represents the relative variance of how each content of the alcohol relate with each other and with themselves, similar to the seaborn. And by comparison, the data correlation for quality with pH(-0.058) and the data correlation of quality with sulphates(0.25)have a wide variance, depending on their frequencies. And for the data correlation of fixed acidity with fixed acidity, they have one as their relation since their frequencies are equal. Citric acid to citric acid also have one as their variance relation. Meaning with every content in correlation with each other results to one variance.
#
# ## Histogram
# >Description of the Histogram
#
# The histogram for both the free sulfur dioxide and density shows the highest frequency occured
